# %%
# 1. Connect to your Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 2. Set up your GitHub credentials
import os
GITHUB_USER = "SaadDevCs"
GITHUB_EMAIL = "greathex.contact@gmail.com" # Put your GitHub email here
GITHUB_TOKEN = "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"    # Paste your token here
REPO_NAME = "Offline-Malaria-RAG-Eval"

# Configure Git
# !git config --global user.email {GITHUB_EMAIL}
# !git config --global user.name {GITHUB_USER}

# 3. Clone your repository into Colab
# !git clone https://{GITHUB_TOKEN}@github.com/{GITHUB_USER}/{REPO_NAME}.git
# %cd {REPO_NAME}

# 4. Copy the processed files from your Drive to the GitHub folder
# UPDATE THE PATH BELOW to wherever your files are in your Drive!
# !cp -r /content/drive/MyDrive/processed_docs/* .

# 5. Push the files to GitHub!
# !git add .
# !git commit -m "Uploading processed RAG evaluation documents directly from Drive"
# !git push origin main
# Out:
# Cloning into 'Offline-Malaria-RAG-Eval'...
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 7 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (7/7), 47.54 KiB | 1.83 MiB/s, done.
# /content/Offline-Malaria-RAG-Eval/Offline-Malaria-RAG-Eval
